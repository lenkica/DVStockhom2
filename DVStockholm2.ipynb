# %%
import pandas as pd
import datetime
import plotly.graph_objects as go
import numpy as np
football_data = pd.read_csv("https://raw.githubusercontent.com/Dataviz-Stockholm/challenges/main/Challenge_two-Beautiful-game/Allsvenskan%20-%20Winner%20each%20season.csv")
football_data.head()
# Out:
#    Year             Team
# 0  1925             Gais
# 1  1926       Örgryte IS
# 2  1927             Gais
# 3  1928       Örgryte IS
# 4  1929  Hälsingborgs IF

# %%
type("Year")
type("Team")
football_data["Year"].unique()
# Out:
# array([1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935,
#        1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946,
#        1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959,  160, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
#replace 160 with 1960
football_data["Year"].replace(" 160","1960", inplace=True)

football_data["Year"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 35
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-5d5eb2a3c647> in <module>
# ...

# %%
# check the values of  
# each row for each column 
n = football_data.nunique(axis=0) 
  
print("No.of.unique values in each column :\n", 
      n)
# Out:
# No.of.unique values in each column :
#  Year    95
# Team    22
# dtype: int64

# %%
#https://seaborn.pydata.org/generated/seaborn.stripplot.html
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.stripplot(x="Year", y="Team", data=football_data)
